# %% [markdown]
# <a href="https://colab.research.google.com/github/amy-151pina/london_housing_case_study/blob/main/15_3_london_housing_case_study.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Springboard Data Science Career Track Unit 4 Challenge - Tier 3 Complete
#
# ## Objectives
# Hey! Great job getting through those challenging DataCamp courses. You're learning a lot in a short span of time.
#
# In this notebook, you're going to apply the skills you've been learning, bridging the gap between the controlled environment of DataCamp and the *slightly* messier work that data scientists do with actual datasets!
#
# Here’s the mystery we’re going to solve: ***which boroughs of London have seen the greatest increase in housing prices, on average, over the last two decades?***
#
#
# A borough is just a fancy word for district. You may be familiar with the five boroughs of New York… well, there are 32 boroughs within Greater London [(here's some info for the curious)](https://en.wikipedia.org/wiki/London_boroughs). Some of them are more desirable areas to live in, and the data will reflect that with a greater rise in housing prices.
#
# ***This is the Tier 3 notebook, which means it's not filled in at all: we'll just give you the skeleton of a project, the brief and the data. It's up to you to play around with it and see what you can find out! Good luck! If you struggle, feel free to look at easier tiers for help; but try to dip in and out of them, as the more independent work you do, the better it is for your learning!***
#
# This challenge will make use of only what you learned in the following DataCamp courses:
# - Prework courses (Introduction to Python for Data Science, Intermediate Python for Data Science)
# - Data Types for Data Science
# - Python Data Science Toolbox (Part One)
# - pandas Foundations
# - Manipulating DataFrames with pandas
# - Merging DataFrames with pandas
#
# Of the tools, techniques and concepts in the above DataCamp courses, this challenge should require the application of the following:
# - **pandas**
#     - **data ingestion and inspection** (pandas Foundations, Module One)
#     - **exploratory data analysis** (pandas Foundations, Module Two)
#     - **tidying and cleaning** (Manipulating DataFrames with pandas, Module Three)
#     - **transforming DataFrames** (Manipulating DataFrames with pandas, Module One)
#     - **subsetting DataFrames with lists** (Manipulating DataFrames with pandas, Module One)
#     - **filtering DataFrames** (Manipulating DataFrames with pandas, Module One)
#     - **grouping data** (Manipulating DataFrames with pandas, Module Four)
#     - **melting data** (Manipulating DataFrames with pandas, Module Three)
#     - **advanced indexing** (Manipulating DataFrames with pandas, Module Four)
# - **matplotlib** (Intermediate Python for Data Science, Module One)
# - **fundamental data types** (Data Types for Data Science, Module One)
# - **dictionaries** (Intermediate Python for Data Science, Module Two)
# - **handling dates and times** (Data Types for Data Science, Module Four)
# - **function definition** (Python Data Science Toolbox - Part One, Module One)
# - **default arguments, variable length, and scope** (Python Data Science Toolbox - Part One, Module Two)
# - **lambda functions and error handling** (Python Data Science Toolbox - Part One, Module Four)

# %% [markdown]
# ## The Data Science Pipeline
#
# This is Tier Three, so we'll get you started. But after that, it's all in your hands! When you feel done with your investigations, look back over what you've accomplished, and prepare a quick presentation of your findings for the next mentor meeting.
#
# Data Science is magical. In this case study, you'll get to apply some complex machine learning algorithms. But as  [David Spiegelhalter](https://www.youtube.com/watch?v=oUs1uvsz0Ok) reminds us, there is no substitute for simply **taking a really, really good look at the data.** Sometimes, this is all we need to answer our question.
#
# Data Science projects generally adhere to the four stages of Data Science Pipeline:
# 1. Sourcing and loading
# 2. Cleaning, transforming, and visualizing
# 3. Modeling
# 4. Evaluating and concluding

# %% [markdown]
# ### 1. Sourcing and Loading
#
# Any Data Science project kicks off by importing  ***pandas***. The documentation of this wonderful library can be found [here](https://pandas.pydata.org/). As you've seen, pandas is conveniently connected to the [Numpy](http://www.numpy.org/) and [Matplotlib](https://matplotlib.org/) libraries.
#
# ***Hint:*** This part of the data science pipeline will test those skills you acquired in the pandas Foundations course, Module One.

# %% [markdown]
# #### 1.1. Importing Libraries

# %%
# Let's import the pandas, numpy libraries as pd, and np respectively.
import pandas as pd
import numpy as np

# Load the pyplot collection of functions from matplotlib, as plt
from matplotlib import pyplot as plt

# %% [markdown]
# #### 1.2.  Loading the data
# Your data comes from the [London Datastore](https://data.london.gov.uk/): a free, open-source data-sharing portal for London-oriented datasets.

# %%
# First, make a variable called url_LondonHousePrices, and assign it the following link, enclosed in quotation-marks as a string:
# https://data.london.gov.uk/download/uk-house-price-index/70ac0766-8902-4eb5-aab5-01951aaed773/UK%20House%20price%20index.xls

url_LondonHousePrices = "https://data.london.gov.uk/download/uk-house-price-index/70ac0766-8902-4eb5-aab5-01951aaed773/UK%20House%20price%20index.xls"

# The dataset we're interested in contains the Average prices of the houses, and is actually on a particular sheet of the Excel file.
# As a result, we need to specify the sheet name in the read_excel() method.
# Put this data into a variable called properties.
properties = pd.read_excel(url_LondonHousePrices, sheet_name='Average price', index_col= None)

# %% [markdown]
# ### 2. Cleaning, transforming, and visualizing
# This second stage is arguably the most important part of any Data Science project. The first thing to do is take a proper look at the data. Cleaning forms the majority of this stage, and can be done both before or after Transformation.
#
# The end goal of data cleaning is to have tidy data. When data is tidy:
#
# 1. Each variable has a column.
# 2. Each observation forms a row.
#
# Keep the end goal in mind as you move through this process, every step will take you closer.
#
#
#
# ***Hint:*** This part of the data science pipeline should test those skills you acquired in:
# - Intermediate Python for data science, all modules.
# - pandas Foundations, all modules.
# - Manipulating DataFrames with pandas, all modules.
# - Data Types for Data Science, Module Four.
# - Python Data Science Toolbox - Part One, all modules

# %% [markdown]
# **2.1. Exploring your data**
#
# Think about your pandas functions for checking out a dataframe.

# %%
# checking dataframe
properties.head()
# Out:
#   Unnamed: 0 City of London Barking & Dagenham       Barnet       Bexley  \
# 0        NaT      E09000001          E09000002    E09000003    E09000004
# 1 1995-01-01    91448.98487         50460.2266  93284.51832  64958.09036
# 2 1995-02-01    82202.77314        51085.77983  93190.16963  64787.92069
# 3 1995-03-01    79120.70256        51268.96956  92247.52435  64367.49344
# 4 1995-04-01    77101.20804        53133.50526  90762.87492  64277.66881
#
#          Brent      Bromley       Camden      Croydon       Ealing  ...  \
# 0    E09000005    E09000006    E09000007    E09000008    E09000009  ...
# 1  71306.56698  81671.47692  120932.8881  69158.16225  79885.89069  ...
# 2  72022.26197  81657.55944  119508.8622  68951.09542  80897.06551  ...
# 3  72015.76274  81449.31143  120282.2131  68712.44341  81379.86288  ...
# 4  72965.63094  81124.41227   120097.899  68610.04641  82188.90498  ...
#
#     NORTH WEST YORKS & THE HUMBER EAST MIDLANDS WEST MIDLANDS EAST OF ENGLAND  \
# ...

# %%
# checking dataframe
properties.info
# Out:
# <bound method DataFrame.info of     Unnamed: 0 City of London Barking & Dagenham       Barnet       Bexley  \
# 0          NaT      E09000001          E09000002    E09000003    E09000004
# 1   1995-01-01    91448.98487         50460.2266  93284.51832  64958.09036
# 2   1995-02-01    82202.77314        51085.77983  93190.16963  64787.92069
# 3   1995-03-01    79120.70256        51268.96956  92247.52435  64367.49344
# 4   1995-04-01    77101.20804        53133.50526  90762.87492  64277.66881
# ..         ...            ...                ...          ...          ...
# 343 2023-07-01         973133             341446       575129       387566
# 344 2023-08-01         901625             341710       585896       386939
# 345 2023-09-01         875029             339983       586665       388778
# 346 2023-10-01         831708             341370       579777       385477
# 347 2023-11-01         727023             353585       581265       381785
#
# ...

# %%
# checking dataframe
properties.shape
# Out:
# (348, 49)

# %%
# checking dataframe
properties.describe()
# Out:
#        Unnamed: 34  Unnamed: 37  Unnamed: 47
# count          0.0          0.0          0.0
# mean           NaN          NaN          NaN
# std            NaN          NaN          NaN
# min            NaN          NaN          NaN
# 25%            NaN          NaN          NaN
# 50%            NaN          NaN          NaN
# 75%            NaN          NaN          NaN
# max            NaN          NaN          NaN

# %% [markdown]
# **2.2. Cleaning the data**
#
# You might find you need to transpose your dataframe, check out what its row indexes are, and reset the index. You  also might find you need to assign the values of the first row to your column headings  . (Hint: recall the .columns feature of DataFrames, as well as the iloc[] method).
#
# Don't be afraid to use StackOverflow for help  with this.

# %%
# transpose data
properties_trans = properties.transpose()

# %%
# checking dataframe
properties_trans.head()
# Out:
#                           0                    1                    2    \
# Unnamed: 0                NaT  1995-01-01 00:00:00  1995-02-01 00:00:00
# City of London      E09000001          91448.98487          82202.77314
# Barking & Dagenham  E09000002           50460.2266          51085.77983
# Barnet              E09000003          93284.51832          93190.16963
# Bexley              E09000004          64958.09036          64787.92069
#
#                                     3                    4    \
# Unnamed: 0          1995-03-01 00:00:00  1995-04-01 00:00:00
# City of London              79120.70256          77101.20804
# Barking & Dagenham          51268.96956          53133.50526
# Barnet                      92247.52435          90762.87492
# Bexley                      64367.49344          64277.66881
#
#                                     5                    6    \
# Unnamed: 0          1995-05-01 00:00:00  1995-06-01 00:00:00
# ...

# %%
# assigning values of first row to column headers
properties_trans.columns = properties_trans.iloc[0]

# %%
# removing first row of data
properties_trans.drop(properties_trans.index[0], inplace=True)

# %%
# resetting index
properties_trans = properties_trans.reset_index()

# %% [markdown]
# **2.3. Cleaning the data (part 2)**
#
# You might we have to **rename** a couple columns. How do you do this? The clue's pretty bold...

# %%
# rename colummns to borough and id columns

properties_trans.rename(columns={'Unnamed: 0':'index', 'index':'borough', pd.NaT:'id'}, inplace=True)

# %%
properties_trans.head()
# Out:
# Unnamed: 0             borough         id 1995-01-01 00:00:00  \
# 0               City of London  E09000001         91448.98487
# 1           Barking & Dagenham  E09000002          50460.2266
# 2                       Barnet  E09000003         93284.51832
# 3                       Bexley  E09000004         64958.09036
# 4                        Brent  E09000005         71306.56698
#
# Unnamed: 0 1995-02-01 00:00:00 1995-03-01 00:00:00 1995-04-01 00:00:00  \
# 0                  82202.77314         79120.70256         77101.20804
# 1                  51085.77983         51268.96956         53133.50526
# 2                  93190.16963         92247.52435         90762.87492
# 3                  64787.92069         64367.49344         64277.66881
# 4                  72022.26197         72015.76274         72965.63094
#
# Unnamed: 0 1995-05-01 00:00:00 1995-06-01 00:00:00 1995-07-01 00:00:00  \
# 0                  84409.14932         94900.51244         110128.0423
# ...

# %% [markdown]
# **2.4.Transforming the data**
#
# Remember what Wes McKinney said about tidy data?
#
# You might need to **melt** your DataFrame here.

# %%
# melt to tidy data principles; each column a variable, each row an observation
properties_clean = pd.melt(properties_trans, id_vars=['borough', 'id'])

# %%
# check dataframe
properties_clean.head()
# Out:
#               borough         id Unnamed: 0        value
# 0      City of London  E09000001 1995-01-01  91448.98487
# 1  Barking & Dagenham  E09000002 1995-01-01   50460.2266
# 2              Barnet  E09000003 1995-01-01  93284.51832
# 3              Bexley  E09000004 1995-01-01  64958.09036
# 4               Brent  E09000005 1995-01-01  71306.56698

# %%
# rename date and average price columns
properties_clean.rename(columns={'Unnamed: 0':'date', 'value':'avg_price'}, inplace=True)

# %% [markdown]
# Remember to make sure your column data types are all correct. Average prices, for example, should be floating point numbers...

# %%
# check column data types
properties_clean.dtypes
# Out:
# borough              object
# id                   object
# date         datetime64[ns]
# avg_price            object
# dtype: object

# %%
# change average price column data type to numeric
properties_clean['avg_price'] = pd.to_numeric(properties_clean['avg_price'])

# %% [markdown]
# **2.5. Cleaning the data (part 3)**
#
# Do we have an equal number of observations in the ID, Average Price, Month, and London Borough columns? Remember that there are only 32 London Boroughs. How many entries do you have in that column?
#
# Check out the contents of the London Borough column, and if you find null values, get rid of them however you see fit.

# %%
#check for columns with null values
properties_clean.isnull().any()
# Out:
# borough      False
# id            True
# date         False
# avg_price     True
# dtype: bool

# %%
# check # of unique borough names; should be 32
properties_clean['borough'].nunique()
# Out:
# 48

# %%
# count # of values in each column
properties_clean.count()
# Out:
# borough      16656
# id           15615
# date         16656
# avg_price    15615
# dtype: int64

# %%
# check unique values of the 'borough' column - call .unique method on 'borough' column
borough_list = properties_clean['borough'].unique()
print(sorted(borough_list))
# Out:
# ['Barking & Dagenham', 'Barnet', 'Bexley', 'Brent', 'Bromley', 'Camden', 'City of London', 'Croydon', 'EAST MIDLANDS', 'EAST OF ENGLAND', 'Ealing', 'Enfield', 'England', 'Greenwich', 'Hackney', 'Hammersmith & Fulham', 'Haringey', 'Harrow', 'Havering', 'Hillingdon', 'Hounslow', 'Inner London', 'Islington', 'Kensington & Chelsea', 'Kingston upon Thames', 'LONDON', 'Lambeth', 'Lewisham', 'Merton', 'NORTH EAST', 'NORTH WEST', 'Newham', 'Outer London', 'Redbridge', 'Richmond upon Thames', 'SOUTH EAST', 'SOUTH WEST', 'Southwark', 'Sutton', 'Tower Hamlets', 'Unnamed: 34', 'Unnamed: 37', 'Unnamed: 47', 'WEST MIDLANDS', 'Waltham Forest', 'Wandsworth', 'Westminster', 'YORKS & THE HUMBER']

# %%
# subset properties_clean to check data in rows where borough is 'unnamed'
properties_clean[properties_clean['borough'] == 'Unnamed: 34'].head()
# Out:
#          borough   id       date  avg_price
# 33   Unnamed: 34  NaN 1995-01-01        NaN
# 81   Unnamed: 34  NaN 1995-02-01        NaN
# 129  Unnamed: 34  NaN 1995-03-01        NaN
# 177  Unnamed: 34  NaN 1995-04-01        NaN
# 225  Unnamed: 34  NaN 1995-05-01        NaN

# %%
# subset properties_clean to check data in rows where borough is 'unnamed'
properties_clean[properties_clean['borough']=='Unnamed: 37'].head()
# Out:
#          borough   id       date  avg_price
# 36   Unnamed: 37  NaN 1995-01-01        NaN
# 84   Unnamed: 37  NaN 1995-02-01        NaN
# 132  Unnamed: 37  NaN 1995-03-01        NaN
# 180  Unnamed: 37  NaN 1995-04-01        NaN
# 228  Unnamed: 37  NaN 1995-05-01        NaN

# %%
# subset properties_clean to check data in rows where borough is 'unnamed'
properties_clean[properties_clean['borough'] == 'Unnamed: 47'].head()
# Out:
#          borough   id       date  avg_price
# 46   Unnamed: 47  NaN 1995-01-01        NaN
# 94   Unnamed: 47  NaN 1995-02-01        NaN
# 142  Unnamed: 47  NaN 1995-03-01        NaN
# 190  Unnamed: 47  NaN 1995-04-01        NaN
# 238  Unnamed: 47  NaN 1995-05-01        NaN

# %%
# subset properties_clean to show rows where id is null
properties_clean[properties_clean['id'].isna()]
# Out:
#            borough   id       date  avg_price
# 33     Unnamed: 34  NaN 1995-01-01        NaN
# 36     Unnamed: 37  NaN 1995-01-01        NaN
# 46     Unnamed: 47  NaN 1995-01-01        NaN
# 81     Unnamed: 34  NaN 1995-02-01        NaN
# 84     Unnamed: 37  NaN 1995-02-01        NaN
# ...            ...  ...        ...        ...
# 16596  Unnamed: 37  NaN 2023-10-01        NaN
# 16606  Unnamed: 47  NaN 2023-10-01        NaN
# 16641  Unnamed: 34  NaN 2023-11-01        NaN
# 16644  Unnamed: 37  NaN 2023-11-01        NaN
# 16654  Unnamed: 47  NaN 2023-11-01        NaN
#
# [1041 rows x 4 columns]

# %%
# method 1: use .notna() method to remove null values
null_free_df1 = properties_clean[properties_clean['avg_price'].notna()]
null_free_df1.head(48)
# Out:
#                  borough         id       date     avg_price
# 0         City of London  E09000001 1995-01-01   91448.98487
# 1     Barking & Dagenham  E09000002 1995-01-01   50460.22660
# 2                 Barnet  E09000003 1995-01-01   93284.51832
# 3                 Bexley  E09000004 1995-01-01   64958.09036
# 4                  Brent  E09000005 1995-01-01   71306.56698
# 5                Bromley  E09000006 1995-01-01   81671.47692
# 6                 Camden  E09000007 1995-01-01  120932.88810
# 7                Croydon  E09000008 1995-01-01   69158.16225
# 8                 Ealing  E09000009 1995-01-01   79885.89069
# 9                Enfield  E09000010 1995-01-01   72514.69096
# 10             Greenwich  E09000011 1995-01-01   62300.10169
# 11               Hackney  E09000012 1995-01-01   61296.52637
# 12  Hammersmith & Fulham  E09000013 1995-01-01  124902.86020
# 13              Haringey  E09000014 1995-01-01   76287.56947
# ...

# %%
# use .count() method to check # of values for each column in new dataframe
null_free_df1.count()
# Out:
# borough      15615
# id           15615
# date         15615
# avg_price    15615
# dtype: int64

# %%
# method 2: use .dropna() to drop all null values
null_free_df2 = properties_clean.dropna()
null_free_df2.head(48)
# Out:
#                  borough         id       date     avg_price
# 0         City of London  E09000001 1995-01-01   91448.98487
# 1     Barking & Dagenham  E09000002 1995-01-01   50460.22660
# 2                 Barnet  E09000003 1995-01-01   93284.51832
# 3                 Bexley  E09000004 1995-01-01   64958.09036
# 4                  Brent  E09000005 1995-01-01   71306.56698
# 5                Bromley  E09000006 1995-01-01   81671.47692
# 6                 Camden  E09000007 1995-01-01  120932.88810
# 7                Croydon  E09000008 1995-01-01   69158.16225
# 8                 Ealing  E09000009 1995-01-01   79885.89069
# 9                Enfield  E09000010 1995-01-01   72514.69096
# 10             Greenwich  E09000011 1995-01-01   62300.10169
# 11               Hackney  E09000012 1995-01-01   61296.52637
# 12  Hammersmith & Fulham  E09000013 1995-01-01  124902.86020
# 13              Haringey  E09000014 1995-01-01   76287.56947
# ...

# %%
# use .count() method to check # of values for each column in new dataframe
null_free_df2.count()
# Out:
# borough      15615
# id           15615
# date         15615
# avg_price    15615
# dtype: int64

# %%
#drop the rest of the rows with invalid borough values
null_free_df2['borough'].unique()
# Out:
# array(['City of London', 'Barking & Dagenham', 'Barnet', 'Bexley',
#        'Brent', 'Bromley', 'Camden', 'Croydon', 'Ealing', 'Enfield',
#        'Greenwich', 'Hackney', 'Hammersmith & Fulham', 'Haringey',
#        'Harrow', 'Havering', 'Hillingdon', 'Hounslow', 'Islington',
#        'Kensington & Chelsea', 'Kingston upon Thames', 'Lambeth',
#        'Lewisham', 'Merton', 'Newham', 'Redbridge',
#        'Richmond upon Thames', 'Southwark', 'Sutton', 'Tower Hamlets',
#        'Waltham Forest', 'Wandsworth', 'Westminster', 'Inner London',
#        'Outer London', 'NORTH EAST', 'NORTH WEST', 'YORKS & THE HUMBER',
#        'EAST MIDLANDS', 'WEST MIDLANDS', 'EAST OF ENGLAND', 'LONDON',
#        'SOUTH EAST', 'SOUTH WEST', 'England'], dtype=object)

# %%
#create list of 32 london boroughs. remove rows that have borough value not included in this list
boroughs32 = ['Camden', 'Greenwich', 'Hackney', 'Hammersmith & Fulham', 'Islington', 'Kensington & Chelsea', 'Lambeth', 'Lewisham', 'Southwark', 'Tower Hamlets', 'Wandsworth', 'Westminster', 'Barking & Dagenham', 'Barnet', 'Bexley', 'Brent', 'Bromley', 'Croydon', 'Ealing', 'Enfield', 'Haringey', 'Harrow', 'Havering', 'Hillingdon', 'Hounslow', 'Kingston upon Thames', 'Merton', 'Newham', 'Redbridge', 'Richmond upon Thames', 'Sutton', 'Waltham Forest']

null_free_df2[null_free_df2['borough'].isin(boroughs32)]
# Out:
#                   borough         id       date     avg_price
# 1      Barking & Dagenham  E09000002 1995-01-01   50460.22660
# 2                  Barnet  E09000003 1995-01-01   93284.51832
# 3                  Bexley  E09000004 1995-01-01   64958.09036
# 4                   Brent  E09000005 1995-01-01   71306.56698
# 5                 Bromley  E09000006 1995-01-01   81671.47692
# ...                   ...        ...        ...           ...
# 16636              Sutton  E09000029 2023-11-01  423148.00000
# 16637       Tower Hamlets  E09000030 2023-11-01  438709.00000
# 16638      Waltham Forest  E09000031 2023-11-01  502114.00000
# 16639          Wandsworth  E09000032 2023-11-01  625786.00000
# 16640         Westminster  E09000033 2023-11-01  870963.00000
#
# [11104 rows x 4 columns]

# %%
# assign new dataframe to df
df = null_free_df2[null_free_df2['borough'].isin(boroughs32)]

# %%
# check #  of unique boroughs again; should be 32
df['borough'].nunique()
# Out:
# 32

# %%
# check dataframe
df.head()
# Out:
#               borough         id       date    avg_price
# 1  Barking & Dagenham  E09000002 1995-01-01  50460.22660
# 2              Barnet  E09000003 1995-01-01  93284.51832
# 3              Bexley  E09000004 1995-01-01  64958.09036
# 4               Brent  E09000005 1995-01-01  71306.56698
# 5             Bromley  E09000006 1995-01-01  81671.47692

# %%
#check data types for each column
df.dtypes
# Out:
# borough              object
# id                   object
# date         datetime64[ns]
# avg_price           float64
# dtype: object

# %% [markdown]
# **2.6. Visualizing the data**
#
# To visualize the data, why not subset on a particular London Borough? Maybe do a line plot of Month against Average Price?

# %%
#subset data on 'Barking & Dagenham' borough
bark_dag_prices = df[df['borough']=='Barking & Dagenham']

#create a line plot of date v. avg_price
bark_dag_prices.plot(x='date', y='avg_price', kind='line')
# Out:
# <Axes: xlabel='date'>

# %% [markdown]
# To limit the number of data points you have, you might want to extract the year from every month value your *Month* column.
#
# To this end, you *could* apply a ***lambda function***. Your logic could work as follows:
# 1. look through the `Month` column
# 2. extract the year from each individual value in that column
# 3. store that corresponding year as separate column.
#
# Whether you go ahead with this is up to you. Just so long as you answer our initial brief: which boroughs of London have seen the greatest house price increase, on average, over the past two decades?

# %%
# add 'year' column
df['year'] = df['date'].apply(lambda t: t.year)
# Out:
# <ipython-input-38-c6b13c048231>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['year'] = df['date'].apply(lambda t: t.year)

# %%
#check dataframe using .tail()
df.tail()
# Out:
#               borough         id       date  avg_price  year
# 16636          Sutton  E09000029 2023-11-01   423148.0  2023
# 16637   Tower Hamlets  E09000030 2023-11-01   438709.0  2023
# 16638  Waltham Forest  E09000031 2023-11-01   502114.0  2023
# 16639      Wandsworth  E09000032 2023-11-01   625786.0  2023
# 16640     Westminster  E09000033 2023-11-01   870963.0  2023

# %%
# determine average price as grouped by borough and year
avg_price_by_bor = df.groupby(['borough', 'year']).mean()
avg_price_by_bor.sample(10)
# Out:
# <ipython-input-40-51de49e8af2f>:2: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   avg_price_by_bor = df.groupby(['borough', 'year']).mean()
#                                avg_price
# borough              year
# Kingston upon Thames 2004  246424.125283
# Greenwich            2011  229295.398225
# Bexley               2005  186512.186267
# Lewisham             2002  143764.029800
# Hammersmith & Fulham 2009  435456.444217
# Camden               2000  247114.633575
# Bexley               2023  390358.272727
# Haringey             2016  527676.611050
# Brent                2007  286995.347067
# Greenwich            2015  331848.808558

# %%
#reset index
dfg = avg_price_by_bor.reset_index()
dfg.head()
# Out:
#               borough  year     avg_price
# 0  Barking & Dagenham  1995  51817.969390
# 1  Barking & Dagenham  1996  51718.192690
# 2  Barking & Dagenham  1997  55974.262309
# 3  Barking & Dagenham  1998  60285.821083
# 4  Barking & Dagenham  1999  65320.934441

# %% [markdown]
# **3. Modeling**
#
# Consider creating a function that will calculate a ratio of house prices, comparing the price of a house in 2018 to the price in 1998.
#
# Consider calling this function create_price_ratio.
#
# You'd want this function to:
# 1. Take a filter of dfg, specifically where this filter constrains the London_Borough, as an argument. For example, one admissible argument should be: dfg[dfg['London_Borough']=='Camden'].
# 2. Get the Average Price for that Borough, for the years 1998 and 2018.
# 4. Calculate the ratio of the Average Price for 1998 divided by the Average Price for 2018.
# 5. Return that ratio.
#
# Once you've written this function, you ultimately want to use it to iterate through all the unique London_Boroughs and work out the ratio capturing the difference of house prices between 1998 and 2018.
#
# Bear in mind: you don't have to write a function like this if you don't want to. If you can solve the brief otherwise, then great!
#
# ***Hint***: This section should test the skills you acquired in:
# - Python Data Science Toolbox - Part One, all modules

# %%
# function to determine ratio of avg_price between 1998 and 2018
def create_price_ratio(d):
  y1998 = float(d['avg_price'][d['year']==1998])
  y2018 = float(d['avg_price'][d['year']==2018])
  ratio = [y1998/y2018]
  return ratio

# %%
# testing function create_price_by_ratio(d)
create_price_ratio(dfg[dfg['borough']=='Barking & Dagenham'])
# Out:
# [0.20422256235393685]

# %%
# we want to determine ratio for all 32 london boroughs
# making empty dictionary, called final, to store ratios for each unique london borough

final = {}

# %%
# declare for loop to iterate through each unique elemnt of 'borough' column of DataFrame dfg
for b in dfg['borough'].unique():
  # make parameter to create_price_ratio function:, ie, subset dfg on 'borough' = b
  borough = dfg[dfg['borough']==b]
  # make a new entry in the final dictionary whos value is the result of calling create_price_ratio with the argument: borough\
  final[b] = create_price_ratio(borough)
# use the function and incorporate that into a new key in the dictionary
print(final)
# Out:
# {'Barking & Dagenham': [0.20422256235393685], 'Barnet': [0.229452741207858], 'Bexley': [0.2353507654063011], 'Brent': [0.2043086864360114], 'Bromley': [0.24421308489837315], 'Camden': [0.20261973503252542], 'Croydon': [0.23803288028014052], 'Ealing': [0.23194048191708755], 'Enfield': [0.23455064269011858], 'Greenwich': [0.20995010893854213], 'Hackney': [0.16133493530705728], 'Hammersmith & Fulham': [0.24167443054605847], 'Haringey': [0.19475619095546956], 'Harrow': [0.24635417785626296], 'Havering': [0.2312015578701476], 'Hillingdon': [0.23807975835429931], 'Hounslow': [0.25148317824115635], 'Islington': [0.20643891170300288], 'Kensington & Chelsea': [0.19675491852791563], 'Kingston upon Thames': [0.2341619023428255], 'Lambeth': [0.20170435486140825], 'Lewisham': [0.18351246764721704], 'Merton': [0.21091380604361798], 'Newham': [0.18848754146121072], 'Redbridge': [0.2236545053715767], 'Richmond upon Thames': [0.24967779731157863], 'Southwark': [0.18127484171283456], 'Sutton': [0.2428
# ...

# %%
# assign result of calling the DataFrame method on the dictionary final to df_ratios
df_ratios = pd.DataFrame(final)

# %%
# check variable with .head()
df_ratios.head()
# Out:
#    Barking & Dagenham    Barnet    Bexley     Brent   Bromley   Camden  \
# 0            0.204223  0.229453  0.235351  0.204309  0.244213  0.20262
#
#     Croydon   Ealing   Enfield  Greenwich  ...    Merton    Newham  Redbridge  \
# 0  0.238033  0.23194  0.234551    0.20995  ...  0.210914  0.188488   0.223655
#
#    Richmond upon Thames  Southwark    Sutton  Tower Hamlets  Waltham Forest  \
# 0              0.249678   0.181275  0.242806       0.216137        0.171387
#
#    Wandsworth  Westminster
# 0    0.210185     0.186791
#
# [1 rows x 32 columns]

# %%
# transpose data and reset index
df_ratios = df_ratios.transpose()
df_ratios = df_ratios.reset_index()

# %%
# check dataframe with .head()
df_ratios.head()
# Out:
#                 index         0
# 0  Barking & Dagenham  0.204223
# 1              Barnet  0.229453
# 2              Bexley  0.235351
# 3               Brent  0.204309
# 4             Bromley  0.244213

# %%
# rename 'index' column as 'borough' and '0' column as '2018'
df_ratios.rename(columns={'index':'borough', 0:'2018'}, inplace=True)
df_ratios.head()
# Out:
#               borough      2018
# 0  Barking & Dagenham  0.204223
# 1              Barnet  0.229453
# 2              Bexley  0.235351
# 3               Brent  0.204309
# 4             Bromley  0.244213

# %%
# sort in descending order and select top 15 boroughs
# make variable called top15, and assign it the result of calling sort_values() on df_ratios
top15 = df_ratios.sort_values(by='2018', ascending=False).head(15)
print(top15)
# Out:
#                  borough      2018
# 16              Hounslow  0.251483
# 25  Richmond upon Thames  0.249678
# 13                Harrow  0.246354
# 4                Bromley  0.244213
# 27                Sutton  0.242806
# 11  Hammersmith & Fulham  0.241674
# 15            Hillingdon  0.238080
# 6                Croydon  0.238033
# 2                 Bexley  0.235351
# 8                Enfield  0.234551
# 19  Kingston upon Thames  0.234162
# 7                 Ealing  0.231940
# 14              Havering  0.231202
# 1                 Barnet  0.229453
# 24             Redbridge  0.223655

# %%
# looking at avg_price for each of bottom 17 boroughs in 2018
bot17 = df_ratios.sort_values(by='2018', ascending=False).tail(17)
print(bot17)
# Out:
#                  borough      2018
# 28         Tower Hamlets  0.216137
# 22                Merton  0.210914
# 30            Wandsworth  0.210185
# 9              Greenwich  0.209950
# 17             Islington  0.206439
# 3                  Brent  0.204309
# 0     Barking & Dagenham  0.204223
# 5                 Camden  0.202620
# 20               Lambeth  0.201704
# 18  Kensington & Chelsea  0.196755
# 12              Haringey  0.194756
# 23                Newham  0.188488
# 31           Westminster  0.186791
# 21              Lewisham  0.183512
# 26             Southwark  0.181275
# 29        Waltham Forest  0.171387
# 10               Hackney  0.161335

# %%
# plot boroughs that have seen the greatest changes in price
# make a variable called ax. Assign it the result of filtering top15 on 'borough' and '2018', then calling plot() with the parameter kind='bar'
ax = top15[['borough', '2018']].plot(kind='bar')

ax.set_xticklabels(top15.borough)
# Out:
# [Text(0, 0, 'Hounslow'),
#  Text(1, 0, 'Richmond upon Thames'),
#  Text(2, 0, 'Harrow'),
#  Text(3, 0, 'Bromley'),
#  Text(4, 0, 'Sutton'),
#  Text(5, 0, 'Hammersmith & Fulham'),
#  Text(6, 0, 'Hillingdon'),
#  Text(7, 0, 'Croydon'),
#  Text(8, 0, 'Bexley'),
#  Text(9, 0, 'Enfield'),
#  Text(10, 0, 'Kingston upon Thames'),
#  Text(11, 0, 'Ealing'),
#  Text(12, 0, 'Havering'),
#  Text(13, 0, 'Barnet'),
#  Text(14, 0, 'Redbridge')]

# %% [markdown]
# ### 4. Conclusion
# What can you conclude? Type out your conclusion below.
#
# Look back at your notebook. Think about how you might summarize what you have done, and prepare a quick presentation on it to your mentor at your next meeting.
#
# We hope you enjoyed this practical project. It should have consolidated your data hygiene and pandas skills by looking at a real-world problem involving just the kind of dataset you might encounter as a budding data scientist. Congratulations, and looking forward to seeing you at the next step in the course!

# %% [markdown]
# [link text](https://)
#
# From our analysis we see that between 1998 and 2018 the average property price saw a steady increase. In 2018 that increase in average property price ranged between 16% in Hackney to 25% in Hounslow.
#
# By plotting the averge price over time on a line graph we were able to visualize this increase. This line graph also shows a sharp decrease in average property prices from 2008 - 2009 which we can reasonable attribute to the domino effect of the US subprime mortgage crisis of 2008. Since 2009 prices have continued to increase.
#
# In 2018 the boroughs with the highest increase in average property price were Hounslow (25.15%), Richmond & Thames (24.97%), and Harrow (24.64%).
